# %% [markdown]
# <h1 style="color: #0B7285; text-align: center;">📊 Data Analytics Project Dashboard</h1>
#
# <h2 style="color: #862E9C;">Exploratory Data Analysis (EDA)</h2>
#
# <div style="background-color: #F8F9FA; padding: 15px; border-left: 5px solid #0B7285; border-radius: 8px;">
# <h3 style="color: #0B7285; margin-top: 0;">🎯 Project Goal</h3>
# <ul style="color: #333; line-height: 1.6;">
#     <li>Analyze <strong>top-paying roles</strong> and <strong>most demanded skills</strong> in Data Analytics.</li>
#     <li>Use <strong>Python</strong> to explore real-world job posting data.</li>
#     <li>Provide insights for <strong>job-seekers</strong> to identify optimal career paths.</li>
# </ul>
# </div>
#
# <div style="background-color: #FFF3CD; padding: 15px; border-left: 5px solid #FFC107; border-radius: 8px; margin-top: 20px;">
# <h3 style="color: #856404; margin-top: 0;">📦 Final Deliverables</h3>
# <ul style="color: #333; line-height: 1.6;">
#     <li>Well-documented <strong>Jupyter Notebooks</strong> demonstrating Python and data analysis skills.</li>
#     <li>A clear <strong>summary report</strong> (README.md) summarizing findings and insights.</li>
#     <li>Project shared on <strong>GitHub</strong> and <strong>LinkedIn</strong>.</li>
# </ul>
# </div>
#
# <div style="background-color: #E7F5FF; padding: 15px; border-radius: 8px; margin-top: 20px;">
# <h3 style="color: #0D6EFD; margin-top: 0;">🔍 Key Questions</h3>
# <ol style="color: #333; line-height: 1.6;">
#     <li>Which roles are most in demand within the data analytics field?</li>
#     <li>What skills are trending and growing in popularity?</li>
#     <li>How do salaries vary by role and skill level?</li>
#     <li>Which skill offers the best balance of <em style="color: #862E9C;">high demand</em> and <em style="color: #F18F01;">high pay</em>?</li>
# </ol>
# </div>
#
# <blockquote style="border-left: 4px solid #20C997; background-color: #D1F2EB; padding: 10px 20px; margin-top: 20px; border-radius: 6px;">
# <p style="margin: 0;"><strong>Note:</strong> The focus is on <strong>U.S. Data Analyst roles</strong>, but the analysis framework can easily be adapted for other regions or job categories.</p>
# </blockquote>
#
# <h3 style="color: #862E9C; padding: 10px; background: linear-gradient(90deg, transparent, #c787deff, transparent); text-align: center; border-radius: 6px;">Roles Covered in This Analysis</h3>
#
# <div style="display: flex; flex-wrap: wrap; gap: 10px; justify-content: center; margin-bottom: 20px;">
#     <span style="background-color: #0B7285; color: white; padding: 6px 12px; border-radius: 15px; font-size: 0.9em;">Data Analyst</span>
# </div>

# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt

# Specify the file format explicitly
dataset = load_dataset('csv', data_files='D:/Udemy/Luke/Python for Data Analytics/DataSets/data_jobs.csv')
df = dataset['train'].to_pandas()

# Data Cleanup

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_plot = df['job_title_short'].value_counts().to_frame()

sns.set_theme(style='ticks')
sns.barplot(data = df_plot , x= 'count' , y='job_title_short' , hue='count' ,palette='dark')
sns.despine()
plt.title('Number of Jobs per Job Title')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# Countries to Explore

# %%
df_plot = df['job_country'].value_counts().to_frame().head(20)

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_country', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Number of Jobs per Country')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# Companies to Explore

# %%
df_plot = df['company_name'].value_counts().to_frame()[1:].head(20)

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Number of Jobs per Company')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# Job Opportunities

# %%
dict_column = {
    'job_work_from_home': 'Work from Home Offered',
    'job_no_degree_mention': 'Degree Requirement',
    'job_health_insurance': 'Health Insurance Offered'
}

fig, ax = plt.subplots(1, 3, figsize=(11, 3.5))

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
    ax[i].set_title(title)

plt.show()

# %% [markdown]
# Exploratory Data Analysis for Data Analysts in the US

# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt

# Specify the file format explicitly
dataset = load_dataset('csv', data_files='D:/Udemy/Luke/Python for Data Analytics/DataSets/data_jobs.csv')
df = dataset['train'].to_pandas()

# Data Cleanup

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# Filter for US Data Analyst roles

# %%
df_DA_US = df[(df['job_country'] == 'United States') & (df['job_title_short'] == 'Data Analyst')]

# %% [markdown]
# Locations to Explore:

# %%
df_plot = df_DA_US['job_location'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_location', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Job Locations for Data Analyst in the US')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# Job Opportunities

# %%
# rewrite the above with a for loop
dict_column = {
    'job_work_from_home': 'Work from Home Offered',
    'job_no_degree_mention': 'Degree Requirement',
    'job_health_insurance': 'Health Insurance Offered'
}

fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df_DA_US[column].value_counts(), labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
    ax[i].set_title(title)

# plt.suptitle('Benefit Analysis of Data Jobs', fontsize=16)
plt.show()

# %% [markdown]
# Companies to Explore:

# %%
df_plot = df_DA_US['company_name'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Companies for Data Analyst in the US')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()
