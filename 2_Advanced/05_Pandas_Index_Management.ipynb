# %% [markdown]
# # 🐼 Pandas Index Management 🗂️
#
# ## ⬇️ Load Data
#
# The first step is to load our data to examine and manage its index.

# %%
# Importing Libraries

import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Specify the file format explicitly
dataset = load_dataset('csv', data_files='D:/Udemy/Luke/Data Analysis Mastering/Python for Data Analytics/DataSets/data_jobs.csv')
df = dataset['train'].to_pandas()

# Data Cleanup

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# d:\anaconda3\envs\haroun_env\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# ### 🏷️ Index Attributes
#
# #### 📝 Notes
# > You can get or set properties of the index, such as its name or data type.
# > - It's helpful for maintaining metadata 🔖 or ensuring index compatibility in operations 🧩.
# > - (`.name`, `.dtype`)
# >   - `.name` 🏷️: The name of the index.
# >   - `.dtype` 🔢: The data type of the index.
#
# Now, let's take a look at our DataFrame. 👀

# %%
df.sample(3)
# Out:
#           job_title_short                  job_title           job_location  \
# 283393      Data Engineer  Data Engineer - CCM Squad  Auckland, New Zealand
# 654936      Data Engineer          AWS Data Engineer               Anywhere
# 402456  Software Engineer             SAS Programmer      Brussels, Belgium
#
#                         job_via job_schedule_type  job_work_from_home  \
# 283393               via Indeed         Full-time               False
# 654936             via LinkedIn         Full-time                True
# 402456  via Emplois Trabajo.org         Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 283393     New Zealand 2023-09-22 07:53:44                   True
# 654936           Sudan 2023-08-13 10:31:11                   True
# 402456         Belgium 2023-04-29 18:27:34                   True
#
#         job_health_insurance  job_country salary_rate  salary_year_avg  \
# 283393                 False  New Zealand        None              NaN
# 654936                 False        Sudan        None              NaN
# 402456                 False      Belgium        None              NaN
#
#         salary_hour_avg  company_name  \
# 283393              NaN      ASB Bank
# 654936              NaN          Dice
# 402456              NaN  The AKKAdemy
#
#                                                job_skills  \
# 283393  ['sql', 'python', 'sql server', 'snowflake', '...
# 654936                                   ['aws', 'spark']
# 402456                       ['sas', 'sas', 'sql', 'sap']
#
#                                           job_type_skills
# 283393  {'cloud': ['snowflake'], 'databases': ['sql se...
# 654936         {'cloud': ['aws'], 'libraries': ['spark']}
# 402456  {'analyst_tools': ['sas', 'sap'], 'programming...

# %% [markdown]
# Let's inspect our index.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Our index is a range of numbers, inspecting the name...

# %%
df.index.name

# %% [markdown]
# It has no name... so let's name it.

# %%
df.index.name = 'job_index'

# %% [markdown]
# Inspecting it.

# %%
df.index.name
# Out:
# 'job_index'

# %%
df.sample(3)
# Out:
#           job_title_short                                          job_title  \
# job_index
# 200488       Data Analyst                                Online Data Analyst
# 87637       Data Engineer                     Data Engineer III - Databricks
# 144735      Data Engineer  Req. for the post Data Engineer II, Indirect S...
#
#                           job_location        job_via job_schedule_type  \
# job_index
# 200488                        Anywhere   via LinkedIn         Part-time
# 87637                   Framingham, MA   via Mendeley         Full-time
# 144735     Hyderabad, Telangana, India  via Shine.com         Full-time
#
#            job_work_from_home          search_location     job_posted_date  \
# job_index
# 200488                   True                Hong Kong 2023-03-10 15:48:44
# 87637                   False  New York, United States 2023-08-24 00:06:20
# 144735                  False                    India 2023-04-24 08:14:19
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 200488                      True                 False      Hong Kong
# 87637                      False                  True  United States
# 144735                      True                 False          India
#
#           salary_rate  salary_year_avg  salary_hour_avg         company_name  \
# job_index
# 200488           None              NaN              NaN  TELUS International
# 87637            None              NaN              NaN           The Lancet
# 144735           None              NaN              NaN               Amazon
#
#                                                   job_skills  \
# job_index
# 200488                                                ['go']
# 87637      ['sql', 'shell', 'python', 'databricks', 'snow...
# 144735     ['c++', 'c#', 'java', 'python', 'golang', 'pow...
#
#                                              job_type_skills
# job_index
# 200488                               {'programming': ['go']}
# 87637      {'cloud': ['databricks', 'snowflake', 'oracle'...
# 144735     {'programming': ['c++', 'c#', 'java', 'python'...

# %% [markdown]
# ### Example 2
# Remember the pivot table we made in the last example? Where we got median yearly salaries for the different job titles. Let's run that code. Then we'll get the index name and the data type of the index using df.index.name and df.index.dtype.

# %%
median_pivot = df.pivot_table(values='salary_year_avg' , index='job_title_short' , aggfunc='median')
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
index_name = median_pivot.index.name
index_name
# Out:
# 'job_title_short'

# %%
index_dtype = median_pivot.index.dtype
index_dtype
# Out:
# dtype('O')

# %% [markdown]
# ### reset_index()
#
# **Notes**
# - reset_index(): Resets the DataFrame’s index to the default integer index. This is particularly useful after operations that alter the index, like sorting or filtering, to simplify further data manipulation.
#
# **Example 1**
#
# When we create new DataFrames by filtering this jacks up our index!

# %%
df_usa = df[df['job_country'] == 'United States']
df_usa.head(5)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# 5           via ZipRecruiter  Contractor and Temp work                True
# 6               via LinkedIn                 Full-time               False
# 9           via ZipRecruiter                 Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States        None              NaN
# 3                         False  United States        None              NaN
# 5                         False  United States        None              NaN
# 6                         False  United States        None              NaN
# 9                         False  United States        None              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 3                      NaN   Southwest Research Institute
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
df_usa.index
# Out:
# Index([     0,      3,      5,      6,      9,     11,     13,     17,     26,
#            27,
#        ...
#        785625, 785626, 785641, 785648, 785651, 785673, 785685, 785692, 785703,
#        785705],
#       dtype='int64', name='job_index', length=206292)

# %% [markdown]
# Index is no longer correctly spaced by 1 increment.

# %%
df_usa.reset_index(inplace=True)
df_usa.head(5)
# Out:
#    job_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# 3       via LinkedIn                 Full-time               False
# 4   via ZipRecruiter                 Full-time                True
#
#            search_location     job_posted_date  job_no_degree_mention  \
# 0     Texas, United States 2023-06-16 13:44:15                  False
# 1     Texas, United States 2023-07-04 13:01:41                   True
# 2                  Georgia 2023-11-07 14:01:59                  False
# 3   Florida, United States 2023-03-27 13:18:18                  False
# 4  New York, United States 2023-04-23 13:02:57                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
# 1                 False  United States        None              NaN
# 2                 False  United States        None              NaN
# 3                 False  United States        None              NaN
# 4                 False  United States        None              NaN
#
#    salary_hour_avg                   company_name  \
# 0              NaN           Boehringer Ingelheim
# 1              NaN   Southwest Research Institute
# 2              NaN                smart folks inc
# 3              NaN  Miracle Software Systems, Inc
# 4              NaN     Radwell International, LLC
#
#                                           job_skills  \
# 0                                               None
# 1  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2                           ['python', 'sql', 'gcp']
# 3  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 4  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills
# 0                                               None
# 1  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2  {'cloud': ['gcp'], 'programming': ['python', '...
# 3  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 4  {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %% [markdown]
# ### 🤔 To Drop or Not to Drop?
#
# > Technically, we could use **.drop()** 🗑️ to remove the `job_index` column.
# >
# > **BUT** ⚠️, if we wanted to perform **merge operations** 🔗 in the future with our original DataFrame, this `job_index` serves as a crucial **unique ID** 🔑 to do that.
#
# ---
#
# ### **Example 2** 🔄
#
# > Let's return to our main DataFrame 📊 with the job postings. We are going to **reset the index** of the pivot table so that `job_title_short` is no longer the index.

# %%
median_pivot.reset_index(inplace=True)
median_pivot
# Out:
#              job_title_short  salary_year_avg
# 0           Business Analyst          85000.0
# 1             Cloud Engineer          90000.0
# 2               Data Analyst          90000.0
# 3              Data Engineer         125000.0
# 4             Data Scientist         127500.0
# 5  Machine Learning Engineer         106415.0
# 6        Senior Data Analyst         111175.0
# 7       Senior Data Engineer         147500.0
# 8      Senior Data Scientist         155500.0
# 9          Software Engineer          99150.0

# %%
df_usa.set_index('job_index', inplace=True)

df_usa.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# 5           via ZipRecruiter  Contractor and Temp work                True
# 6               via LinkedIn                 Full-time               False
# 9           via ZipRecruiter                 Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States        None              NaN
# 3                         False  United States        None              NaN
# 5                         False  United States        None              NaN
# 6                         False  United States        None              NaN
# 9                         False  United States        None              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 3                      NaN   Southwest Research Institute
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %% [markdown]
# **Example 2**
#
# Now that we've reset our index we can set the new index on another column like salary_year_avg.

# %%
median_pivot.set_index('job_title_short', inplace=True)
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %% [markdown]
# ### 📈 sort_index()
#
# #### 📝 Notes
# > `sort_index()`: Sorts the DataFrame by the index (row labels), either ascending or descending. 🔄
# > - This helps in quickly organizing data by the index. 🗂️
# > - It's often used after `set_index()`.
#
# #### ✅ Example
# Back to our pivoted DataFrame 📊, let's sort this new index alphabetically 🔤.

# %%
median_pivot.sort_index(inplace=True)
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0
