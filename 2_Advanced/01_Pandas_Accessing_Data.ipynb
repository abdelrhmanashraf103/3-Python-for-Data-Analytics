# %% [markdown]
# ### 🐼 Pandas Accessing Data 💾
#
# #### 🔍 Review Data
#
# Let's load in the data from a CSV file 📄 using `read_csv` and quickly review it 🔍 using `head()`.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\anaconda3\envs\haroun_env\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\envs\haroun_env\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\envs\haroun_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\envs\haroun_env\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda3\envs\haroun_env\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in d:\anaconda3\envs\haroun_env\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\envs\haroun_env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\anaconda3\envs\haroun_env\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in d:\anaconda3\envs\haroun_env\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\envs\haroun_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\haroun_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# Importing Libraries

import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Specify the file format explicitly
dataset = load_dataset('csv', data_files='D:/Udemy/Luke/Data Analysis Mastering/Python for Data Analytics/DataSets/data_jobs.csv')
df = dataset['train'].to_pandas()

# Data Cleanup

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# d:\anaconda3\envs\haroun_env\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %% [markdown]
# We learned how to get rows using iloc[] before. But we can do a lot more with it. We can actually get rows and columns.

# %% [markdown]
# ### 🎯 `iloc`
#
# #### 📝 Notes
# > `df.iloc[]`: Select rows and columns by position.
#
# #### ✅ Examples
# Using `iloc`, let's:
#
# 1.  ➡️ Get the first row (index 0).
# 2.  🔍 Get the `job_skills` element of the 3rd (index at 2) row.
# 3.  📋 Get the `job_skills` (index 15) and `job_type_skills` (index 16) for the third (index 2) and fourth (index 3) rows.
# 4.  📄 Get the first 12 rows of the DataFrame.
# 5.  📊 Get the first five columns of the DataFrame and all of the rows.
#
# For this, we'll need to know the index numbers for our DataFrame. 🤔

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('D:/Udemy/Luke/Data Analysis Mastering/Python for Data Analytics/2_Advanced/imgs/iloc_visual_1.png')
plt.figure(figsize=(20, 15))  # Select Shape Size
plt.imshow(img)
plt.axis('off')  # Hide Axis
plt.show()

# %% [markdown]
# 1. Get the first row.

# %%
df.iloc[0]
# Out:
# job_title_short                                       Senior Data Engineer
# job_title                Senior Clinical Data Engineer / Principal Clin...
# job_location                                                 Watertown, CT
# job_via                                                    via Work Nearby
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                       Texas, United States
# job_posted_date                                        2023-06-16 13:44:15
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                  United States
# salary_rate                                                           None
# salary_year_avg                                                        NaN
# salary_hour_avg                                                        NaN
# company_name                                          Boehringer Ingelheim
# job_skills                                                            None
# job_type_skills                                                       None
# Name: 0, dtype: object

# %% [markdown]
# 2. Get the job_skills element of the 3rd (index at 2) row.

# %%
df.iloc[0][15]
# Out:
# C:\Users\New Star Computer 25\AppData\Local\Temp\ipykernel_11036\2485859661.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][15]

# %% [markdown]
# **Note: Use** df.iloc[0, 15] **instead of** df.iloc[0][15] **to ensure future compatibility with pandas.**
# The use of chained indexing like df.iloc[0][15] is being deprecated in pandas, as it may lead to ambiguous behavior between positional and label-based access in future versions. By using df.iloc[0, 15], you directly specify the position of the data you want to access, which is clearer and avoids potential future errors when pandas changes how integer keys are interpreted in series indexing.
#
# So we should instead write:

# %%
df.iloc[0,15]

# %% [markdown]
# 3. Get the job_skills (index 15) and job_type_skills (index 16) for the third (index 2) and fourth (index 3) rows.
# To get third (index 2) and fourth (index 3) rows: [2,3]
# To get job_skills and job_type_skills which are index 15 and index 16 retrospectively: [15,16]
# Then you put those two into a list itself to get everything between these two: df.iloc[[2,3],[15,16]]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('D:/Udemy/Luke/Data Analysis Mastering/Python for Data Analytics/2_Advanced/imgs/iloc_visual_2_a.png')
plt.figure(figsize=(20, 15))  # Select Shape Size
plt.imshow(img)
plt.axis('off')     # Hide Axis
plt.show()

# %%
df.iloc[[2,3],[15,16]]
# Out:
#                                           job_skills  \
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
#
#                                      job_type_skills
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...

# %% [markdown]
# ### Preview
# Below are a few more examples of what iloc can do. Pay close attention to these because we'll use them later.
#
# 4. Get the first 10 rows of the DataFrame.

# %%
df.iloc[:9]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
#
#                    job_location             job_via         job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby                 Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México                 Full-time
# 2               Berlin, Germany        via LinkedIn                 Full-time
# 3               San Antonio, TX   via Diversity.com                 Full-time
# 4                Washington, DC  via Clearance Jobs                 Full-time
# 5                      Anywhere    via ZipRecruiter  Contractor and Temp work
# 6                  Dearborn, MI        via LinkedIn                 Full-time
# 7                      Anywhere        via LinkedIn                 Full-time
# 8           Copenhagen, Denmark     via Trabajo.org                 Full-time
#
#    job_work_from_home         search_location     job_posted_date  \
# 0               False    Texas, United States 2023-06-16 13:44:15
# 1               False                  Mexico 2023-01-14 13:18:07
# 2               False                 Germany 2023-10-10 13:14:55
# 3               False    Texas, United States 2023-07-04 13:01:41
# 4               False                   Sudan 2023-08-07 14:29:36
# 5                True                 Georgia 2023-11-07 14:01:59
# 6               False  Florida, United States 2023-03-27 13:18:18
# 7                True                 Romania 2023-12-07 13:40:49
# 8               False                 Denmark 2023-06-05 13:44:34
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
# 5                  False                 False  United States        None
# 6                  False                 False  United States        None
# 7                  False                 False        Romania        None
# 8                  False                 False        Denmark        None
#
#    salary_year_avg  salary_hour_avg                   company_name  \
# 0              NaN              NaN           Boehringer Ingelheim
# 1              NaN              NaN     Hewlett Packard Enterprise
# 2              NaN              NaN       ALPHA Augmented Services
# 3              NaN              NaN   Southwest Research Institute
# 4              NaN              NaN                Kristina Daniel
# 5              NaN              NaN                smart folks inc
# 6              NaN              NaN  Miracle Software Systems, Inc
# 7              NaN              NaN                          Zitec
# 8              NaN              NaN                         Hempel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
# 5                           ['python', 'sql', 'gcp']
# 6  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 7  ['sql', 'nosql', 'gcp', 'azure', 'aws', 'bigqu...
# 8                ['excel', 'powerpoint', 'power bi']
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5  {'cloud': ['gcp'], 'programming': ['python', '...
# 6  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 7  {'cloud': ['gcp', 'azure', 'aws', 'bigquery', ...
# 8  {'analyst_tools': ['excel', 'powerpoint', 'pow...

# %% [markdown]
# 5. Get the first five columns of the DataFrame and all of the rows.

# %%
df.iloc[:,:5]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type
# 0              Full-time
# 1              Full-time
# 2              Full-time
# 3              Full-time
# 4              Full-time
# ...                  ...
# 785736   Pekerjaan tetap
# 785737   Pekerjaan tetap
# 785738   Pekerjaan tetap
# 785739   Pekerjaan tetap
# 785740   Pekerjaan tetap
#
# [785741 rows x 5 columns]

# %% [markdown]
# ### 📍 `loc`
#
# #### 📝 Notes
# > `df.loc[]`: Select rows and columns by position or label.
# - Similar to `df.iloc[]` except we can use labels instead.
#
# #### 💡 Example
# Let's get the same columns we did before but with `loc` instead. Which uses column and row labels. These are:
#
# 1.  ➡️ Get the first row (index 0).
# 2.  🔍 Get the first 10 rows of `job_skills` and `job_type_skills`.
# 3.  📊 Get the first 5 columns and rows 10-20.
# 4.  📄 Get the first 12 rows of the DataFrame.
# 5.  🗄️ Get the first 5 columns of the DataFrame and all the rows.

# %% [markdown]
# 1. Get the first row. This remains the same because the row doesn't have a label.

# %%
df.loc[0]
# Out:
# job_title_short                                       Senior Data Engineer
# job_title                Senior Clinical Data Engineer / Principal Clin...
# job_location                                                 Watertown, CT
# job_via                                                    via Work Nearby
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                       Texas, United States
# job_posted_date                                        2023-06-16 13:44:15
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                  United States
# salary_rate                                                           None
# salary_year_avg                                                        NaN
# salary_hour_avg                                                        NaN
# company_name                                          Boehringer Ingelheim
# job_skills                                                            None
# job_type_skills                                                       None
# Name: 0, dtype: object

# %% [markdown]
# 2. Get the first 10 rows of job_skills and job_type_skills.

# %%
df.loc[:9 , ['job_skills' , 'job_type_skills']]
# Out:
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
# 5                           ['python', 'sql', 'gcp']
# 6  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 7  ['sql', 'nosql', 'gcp', 'azure', 'aws', 'bigqu...
# 8                ['excel', 'powerpoint', 'power bi']
# 9  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5  {'cloud': ['gcp'], 'programming': ['python', '...
# 6  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 7  {'cloud': ['gcp', 'azure', 'aws', 'bigquery', ...
# 8  {'analyst_tools': ['excel', 'powerpoint', 'pow...
# 9  {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %% [markdown]
# 3. Get the first 5 columns and rows 10-20.

# %%
df.loc[10:20 , 'job_title_short' : 'job_work_from_home']
# Out:
#          job_title_short                                    job_title  \
# 10         Data Engineer         Erfahrene*r Data Engineer*in (m/w/d)
# 11         Data Engineer                                Data Engineer
# 12          Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
# 13  Senior Data Engineer                         Senior Data Engineer
# 14         Data Engineer                                Data Engineer
# 15         Data Engineer                                Data Engineer
# 16         Data Engineer                            Big Data Engineer
# 17        Data Scientist                       Data Science Team Lead
# 18          Data Analyst                                 Data Analyst
# 19        Data Scientist                               Data Scientist
# 20        Data Scientist                               Data Scientist
#
#                                        job_location  \
# 10                               Basel, Switzerland
# 11               Colorado Springs, CO   (+3 others)
# 12                                     Lyon, France
# 13                                     New York, NY
# 14  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 15                                     Aberdeen, UK
# 16                         Pune, Maharashtra, India
# 17                                       Laurel, MD
# 18                                   Warsaw, Poland
# 19                         Pune, Maharashtra, India
# 20                                Zaventem, Belgium
#
#                                               job_via  \
# 10                                       via LinkedIn
# 11                                       via The Muse
# 12                                       via Jobijoba
# 13                                       via LinkedIn
# 14                                          via BeBee
# 15                                       via LinkedIn
# 16                                       via LinkedIn
# 17  via APL Careers - Johns Hopkins University App...
# 18                              via Praca Trabajo.org
# 19                                         via Indeed
# 20                                 via BeBee Belgique
#
#            job_schedule_type  job_work_from_home
# 10                 Full-time               False
# 11                 Full-time               False
# 12  Full-time and Internship               False
# 13                 Full-time               False
# 14                 Full-time               False
# 15                 Temp work               False
# 16                 Full-time               False
# 17                 Full-time               False
# 18                 Full-time               False
# 19                 Full-time               False
# 20                 Full-time               False

# %% [markdown]
# 4. Get the first 12 rows of the DataFrame.

# %%
# Method 1
df.head(12)

# Method 2
df.loc[0:11, :]

# Method 3
df.loc[0:11]
# Out:
#          job_title_short                                          job_title  \
# 0   Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1           Data Analyst                                       Data Analyst
# 2          Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4          Data Engineer                             Data Engineer- Sr Jobs
# 5          Data Engineer                                  GCP Data Engineer
# 6   Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7          Data Engineer                                      Data Engineer
# 8       Business Analyst           Technology & Operations Business Analyst
# 9         Data Scientist                                  Data Scientist II
# 10         Data Engineer               Erfahrene*r Data Engineer*in (m/w/d)
# 11         Data Engineer                                      Data Engineer
#
#                           job_location             job_via  \
# 0                        Watertown, CT     via Work Nearby
# 1         Guadalajara, Jalisco, Mexico    via BeBee México
# 2                      Berlin, Germany        via LinkedIn
# 3                      San Antonio, TX   via Diversity.com
# 4                       Washington, DC  via Clearance Jobs
# 5                             Anywhere    via ZipRecruiter
# 6                         Dearborn, MI        via LinkedIn
# 7                             Anywhere        via LinkedIn
# 8                  Copenhagen, Denmark     via Trabajo.org
# 9                             Anywhere    via ZipRecruiter
# 10                  Basel, Switzerland        via LinkedIn
# 11  Colorado Springs, CO   (+3 others)        via The Muse
#
#            job_schedule_type  job_work_from_home          search_location  \
# 0                  Full-time               False     Texas, United States
# 1                  Full-time               False                   Mexico
# 2                  Full-time               False                  Germany
# 3                  Full-time               False     Texas, United States
# 4                  Full-time               False                    Sudan
# 5   Contractor and Temp work                True                  Georgia
# 6                  Full-time               False   Florida, United States
# 7                  Full-time                True                  Romania
# 8                  Full-time               False                  Denmark
# 9                  Full-time                True  New York, United States
# 10                 Full-time               False              Switzerland
# 11                 Full-time               False     Texas, United States
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0  2023-06-16 13:44:15                  False                 False
# 1  2023-01-14 13:18:07                  False                 False
# 2  2023-10-10 13:14:55                  False                 False
# 3  2023-07-04 13:01:41                   True                 False
# 4  2023-08-07 14:29:36                  False                 False
# 5  2023-11-07 14:01:59                  False                 False
# 6  2023-03-27 13:18:18                  False                 False
# 7  2023-12-07 13:40:49                  False                 False
# 8  2023-06-05 13:44:34                  False                 False
# 9  2023-04-23 13:02:57                  False                 False
# 10 2023-04-17 13:27:32                   True                 False
# 11 2023-11-03 13:06:51                  False                  True
#
#       job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0   United States        None              NaN              NaN
# 1          Mexico        None              NaN              NaN
# 2         Germany        None              NaN              NaN
# 3   United States        None              NaN              NaN
# 4           Sudan        None              NaN              NaN
# 5   United States        None              NaN              NaN
# 6   United States        None              NaN              NaN
# 7         Romania        None              NaN              NaN
# 8         Denmark        None              NaN              NaN
# 9   United States        None              NaN              NaN
# 10    Switzerland        None              NaN              NaN
# 11  United States        None              NaN              NaN
#
#                      company_name  \
# 0            Boehringer Ingelheim
# 1      Hewlett Packard Enterprise
# 2        ALPHA Augmented Services
# 3    Southwest Research Institute
# 4                 Kristina Daniel
# 5                 smart folks inc
# 6   Miracle Software Systems, Inc
# 7                           Zitec
# 8                          Hempel
# 9      Radwell International, LLC
# 10                        ROCKEN®
# 11                        Philips
#
#                                            job_skills  \
# 0                                                None
# 1   ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2   ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3   ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4   ['bash', 'python', 'oracle', 'aws', 'ansible',...
# 5                            ['python', 'sql', 'gcp']
# 6   ['sql', 'python', 'java', 'sql server', 'gcp',...
# 7   ['sql', 'nosql', 'gcp', 'azure', 'aws', 'bigqu...
# 8                 ['excel', 'powerpoint', 'power bi']
# 9   ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# 10         ['python', 'databricks', 'azure', 'spark']
# 11                                 ['python', 'qlik']
#
#                                       job_type_skills
# 0                                                None
# 1   {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2   {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3   {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4   {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5   {'cloud': ['gcp'], 'programming': ['python', '...
# 6   {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 7   {'cloud': ['gcp', 'azure', 'aws', 'bigquery', ...
# 8   {'analyst_tools': ['excel', 'powerpoint', 'pow...
# 9   {'analyst_tools': ['excel'], 'cloud': ['azure'...
# 10  {'cloud': ['databricks', 'azure'], 'libraries'...
# 11  {'analyst_tools': ['qlik'], 'programming': ['p...

# %% [markdown]
# 5. Get the first 5 columns of the DataFrame and all the rows.

# %%
# Method 1
df.loc[:, :df.columns[4]]

# Method 2
df.iloc[:, :5]

# Method 3
df.loc[:, df.columns[0]:df.columns[4]]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type
# 0              Full-time
# 1              Full-time
# 2              Full-time
# 3              Full-time
# 4              Full-time
# ...                  ...
# 785736   Pekerjaan tetap
# 785737   Pekerjaan tetap
# 785738   Pekerjaan tetap
# 785739   Pekerjaan tetap
# 785740   Pekerjaan tetap
#
# [785741 rows x 5 columns]
