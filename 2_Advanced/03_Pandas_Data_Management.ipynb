# %% [markdown]
# # 🐼 Pandas Data Management 🗂️
#
# ## ⬇️ Load Data
#
# The first step in managing data is to load it into a DataFrame.

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('csv', data_files='D:/Udemy/Luke/Data Analysis Mastering/Python for Data Analytics/DataSets/data_jobs.csv')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# DataFrame Copy
df_original = df.copy()

# %% [markdown]
# ### 📋 Copy
#
# > 🧠 Recall from the last lesson when we filled in missing values for median salary.
#
# Here, let's make a new DataFrame, `df_altered` ✨, and only make changes to it, leaving the original DataFrame untouched. 🛡️

# %%
# Create new dataframe
df_altered = df_original
df_altered.loc[:5 , 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Let's fill in missing values with the median value.

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered.loc[: , 'salary_year_avg'].fillna(median_salary)

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %% [markdown]
# Now let's inspect the altered DataFrame.

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# That was good...
#
# But what about the original...

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Holdup!! How the heck did df_original get altered!?!
#
# Well both the variables of df_original and df_altered are referencing the same DataFrame.

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                2364250289984
# ID of df_altered:                 2364250289984
# Are the two dataframes the same?  True

# %% [markdown]
# Instead we can use the .copy() method
#
# - copy(): Copy a DataFrame.

# %%
df_original = df.copy()
df_altered = df_original.copy()

print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                2364242158432
# ID of df_altered:                 2362587768992
# Are the two dataframes the same?  False

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Now that we've created a copy of our data, we want to start our analysis. But if we have a large set of data we only want to take a subset of data to make it more manageable. We can use sample() to get a random sample of the data.

# %% [markdown]
# ### 🎲 Sample
#
# #### 📝 Notes
# > `sample()`: Get a random sample of items.
#
# #### ✅ Examples
# Let's get a random sample of the data. You could get a sample with a fixed number of rows. 👉

# %%
df.sample(n=5)
# Out:
#          job_title_short                                          job_title  \
# 444866      Data Analyst  Data Analyst, Data Analytical Department (Ref:...
# 298704     Data Engineer                                      Data Engineer
# 517465    Data Scientist                                  Database Engineer
# 655184  Business Analyst          Business Analyst with English and Italian
# 433765     Data Engineer                              Data Engineer (m/f/d)
#
#                                  job_location                   job_via  \
# 444866                              Hong Kong            via CTgoodjobs
# 298704                            Chester, UK             via WREG Jobs
# 517465  São Paulo, State of São Paulo, Brazil  via Empregos Trabajo.org
# 655184                        Sofia, Bulgaria     via LinkedIn Bulgaria
# 433765                        Berlin, Germany              via LinkedIn
#
#        job_schedule_type  job_work_from_home search_location  \
# 444866         Full-time               False       Hong Kong
# 298704         Full-time               False  United Kingdom
# 517465         Full-time               False          Brazil
# 655184         Full-time               False        Bulgaria
# 433765         Full-time               False         Germany
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 444866 2023-06-20 16:24:39                   True                 False
# 298704 2023-06-16 17:52:13                   True                 False
# 517465 2023-03-22 11:34:52                  False                 False
# 655184 2023-01-28 10:18:38                  False                 False
# 433765 2023-10-20 16:19:01                  False                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 444866       Hong Kong        None              NaN              NaN
# 298704  United Kingdom        None              NaN              NaN
# 517465          Brazil        None              NaN              NaN
# 655184        Bulgaria        None              NaN              NaN
# 433765         Germany        None              NaN              NaN
#
#                                              company_name  \
# 444866  AEON Credit Service (Asia) Co., Ltd. (AEON 信貸財...
# 298704                      Oscar Associates (UK) Limited
# 517465                                         RecargaPay
# 655184                                     DXC Technology
# 433765                                      LOOPING GROUP
#
#                                                job_skills  \
# 444866  ['python', 'sql', 'r', 'vba', 'numpy', 'pandas...
# 298704                                               None
# 517465  ['no-sql', 'mongodb', 'mongodb', 'dynamodb', '...
# 655184                  ['aws', 'vmware', 'excel', 'sap']
# 433765  ['python', 'sql', 'azure', 'databricks', 'reds...
#
#                                           job_type_skills
# 444866  {'analyst_tools': ['excel', 'tableau', 'dataro...
# 298704                                               None
# 517465  {'cloud': ['redshift', 'aws'], 'databases': ['...
# 655184  {'analyst_tools': ['excel', 'sap'], 'cloud': [...
# 433765  {'analyst_tools': ['tableau', 'power bi', 'loo...

# %% [markdown]
# Or you can randomly select a fraction of the data (e.g., 10% of the rows), with or without replacement.

# %%
df.sample(frac=.1 , replace=False)
# Out:
#             job_title_short                                    job_title  \
# 213589        Data Engineer                            Big Data Engineer
# 488141  Senior Data Analyst               Senior Data Analyst- Ecommerce
# 232811  Senior Data Analyst                    Gamma Senior Data Analyst
# 618395         Data Analyst                 Data Analytics Lead, Banking
# 47251         Data Engineer                            Big Data Engineer
# ...                     ...                                          ...
# 181069    Software Engineer                         Software Engineer II
# 533348       Cloud Engineer                  Network Operations Engineer
# 743296        Data Engineer                                Data Engineer
# 21509          Data Analyst        Data Analyst Co-op Spring/Summer 2023
# 439958       Cloud Engineer  Infrastructure Network Services Engineer II
#
#                                       job_location  \
# 213589                 Bengaluru, Karnataka, India
# 488141                    Gurugram, Haryana, India
# 232811                    Bogotá, Bogota, Colombia
# 618395                                New York, NY
# 47251                              Cajamarca, Peru
# ...                                            ...
# 181069                           Budapest, Hungary
# 533348                    Tseung Kwan O, Hong Kong
# 743296                                 England, UK
# 21509                             Seneca Falls, NY
# 439958  San Pedro Garza García, Nuevo Leon, Mexico
#
#                                               job_via  \
# 213589                                     via Indeed
# 488141                                   via Cutshort
# 232811                                      via BeBee
# 618395                               via Startup Jobs
# 47251   via Trabajo.org - Vacantes De Empleo, Trabajo
# ...                                               ...
# 181069                                via Trabajo.org
# 533348                                   via BeBee 香港
# 743296                                      via BeBee
# 21509                                    via LinkedIn
# 439958                                      via BeBee
#
#                job_schedule_type  job_work_from_home          search_location  \
# 213589                 Full-time               False                    India
# 488141                 Full-time               False                    India
# 232811                 Full-time               False                 Colombia
# 618395                 Full-time               False  New York, United States
# 47251                  Full-time               False                     Peru
# ...                          ...                 ...                      ...
# 181069                 Full-time               False                  Hungary
# 533348                 Full-time               False                Hong Kong
# 743296                 Full-time               False           United Kingdom
# 21509   Full-time and Internship               False  New York, United States
# 439958                 Full-time               False                   Mexico
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 213589 2023-01-17 22:13:00                  False                 False
# 488141 2023-04-13 11:17:02                   True                 False
# 232811 2023-08-14 07:21:10                  False                 False
# 618395 2023-07-21 11:59:57                  False                  True
# 47251  2023-09-30 06:47:17                   True                 False
# ...                    ...                    ...                   ...
# 181069 2023-01-16 16:11:22                  False                 False
# 533348 2023-09-25 19:50:35                   True                 False
# 743296 2023-10-25 20:17:00                   True                 False
# 21509  2023-11-30 13:00:40                  False                 False
# 439958 2023-09-11 16:17:10                   True                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 213589           India        None              NaN              NaN
# 488141           India        None              NaN              NaN
# 232811        Colombia        None              NaN              NaN
# 618395   United States        None              NaN              NaN
# 47251             Peru        None              NaN              NaN
# ...                ...         ...              ...              ...
# 181069         Hungary        None              NaN              NaN
# 533348       Hong Kong        None              NaN              NaN
# 743296  United Kingdom        None              NaN              NaN
# 21509    United States        None              NaN              NaN
# 439958          Mexico        None              NaN              NaN
#
#                                       company_name  \
# 213589                                     Maintec
# 488141                                       Qrata
# 232811                     Boston Consulting Group
# 618395                                     Current
# 47251                                      Emprego
# ...                                            ...
# 181069                 Ekata, A Mastercard company
# 533348  Towngas Telecommunications Company Limited
# 743296                                   Aviva plc
# 21509                                     ITT Inc.
# 439958                                    Conduent
#
#                                                job_skills  \
# 213589           ['python', 'hadoop', 'airflow', 'kafka']
# 488141                                         ['python']
# 232811  ['matlab', 'sas', 'sas', 'r', 'python', 'sql',...
# 618395            ['sql', 'python', 'bigquery', 'looker']
# 47251   ['python', 'scala', 'azure', 'databricks', 'sp...
# ...                                                   ...
# 181069  ['scala', 'haskell', 'redis', 'aws', 'databric...
# 533348  ['html', 'css', 'sql', 'php', 'shell', 'powers...
# 743296  ['sql', 'python', 'scala', 'java', 'go', 'orac...
# 21509                                                None
# 439958                                               None
#
#                                           job_type_skills
# 213589  {'libraries': ['hadoop', 'airflow', 'kafka'], ...
# 488141                        {'programming': ['python']}
# 232811  {'analyst_tools': ['sas', 'spss', 'alteryx', '...
# 618395  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 47251   {'cloud': ['azure', 'databricks'], 'libraries'...
# ...                                                   ...
# 181069  {'cloud': ['aws', 'databricks'], 'databases': ...
# 533348  {'os': ['linux'], 'programming': ['html', 'css...
# 743296  {'cloud': ['oracle', 'snowflake', 'aws'], 'pro...
# 21509                                                None
# 439958                                               None
#
# [78574 rows x 17 columns]

# %% [markdown]
# Now you can analyze these subsets of data.
