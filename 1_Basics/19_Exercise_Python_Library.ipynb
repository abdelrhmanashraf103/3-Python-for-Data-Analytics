# %% [markdown]
# <h1 style="color: #0B7285; text-align: center;">🔧 Exercise: Python Library - Data Cleanup</h1>
#
# <h2 style="color: #862E9C;">Problem Statement</h2>
#
# <div style="background-color: #F8F9FA; padding: 15px; border-left: 5px solid #0B7285; border-radius: 8px;">
# <h3 style="color: #0B7285; margin-top: 0;">📋 Problem Description</h3>
# <p style="color: #333; line-height: 1.6;">
# Given a list of dictionaries, each representing a different <strong>job role</strong>, where each dictionary contains:
# </p>
#
# <ul style="color: #333; line-height: 1.6;">
#     <li><code>'job_skills'</code>: A <strong>string value</strong> representing a list of skills</li>
#     <li><code>'job_date'</code>: A <strong>string value</strong> representing a date</li>
# </ul>
#
# <h4 style="color: #0B7285;">🎯 Required Transformations</h4>
# <ul style="color: #333; line-height: 1.6;">
#     <li><strong>Convert</strong> <code>'job_date'</code> from <em>string value</em> to <em>datetime object</em></li>
#     <li><strong>Convert</strong> <code>'job_skills'</code> from <em>string value</em> to <em>actual list object</em></li>
# </ul>
# </div>
#
# <div style="background-color: #FFF3CD; padding: 15px; border-left: 5px solid #FFC107; border-radius: 8px; margin-top: 20px;">
# <h3 style="color: #856404; margin-top: 0;">📦 Data Structure</h3>
# <p style="color: #333; line-height: 1.6;">
# First, create a list called <code>data_science_jobs</code> containing dictionaries. Each dictionary represents a <strong>data science job role</strong>:
# </p>
#
# <div style="background-color: #f8f9fa; padding: 15px; border-radius: 6px; margin: 10px 0;">
# <h4 style="color: #495057;">Dictionary Keys:</h4>
# <ul style="color: #333; line-height: 1.6; margin: 10px 0;">
#     <li><code>'job_title'</code>: <span style="color: #0B7285;">The title of the job</span> (string)</li>
#     <li><code>'job_skills'</code>: <span style="color: #17A2B8;">A string that represents a list of skills required</span><br>
#         <small><em>Example: <code>"['Python', 'SQL', 'Pandas']"</code></em></small>
#     </li>
#     <li><code>'job_date'</code>: <span style="color: #6F42C1;">A string that represents a date</span><br>
#         <small><em>Example: <code>"2024-03-15"</code></em></small>
#     </li>
# </ul>
# </div>
# </div>
#
# <div style="background-color: #E7F5FF; padding: 15px; border-radius: 8px; margin-top: 20px;">
# <h3 style="color: #0D6EFD; margin-top: 0;">🔧 Implementation Requirements</h3>
# <ol style="color: #333; line-height: 1.6;">
#     <li><strong>Create</strong> the <code>data_science_jobs</code> list with sample job role dictionaries</li>
#     <li><strong>Transform</strong> <code>'job_date'</code> strings to <code>datetime</code> objects</li>
#     <li><strong>Parse</strong> <code>'job_skills'</code> strings into actual Python <code>list</code> objects</li>
#     <li><strong>Handle</strong> potential parsing errors gracefully</li>
#     <li><strong>Verify</strong> the data types after transformation</li>
# </ol>
# </div>
#
# <blockquote style="border-left: 4px solid #20C997; background-color: #D1F2EB; padding: 10px 20px; margin-top: 20px; border-radius: 6px;">
# <p style="margin: 0;"><strong>💡 Key Challenge:</strong> Safely convert string representations of Python data structures (lists) without using dangerous <code>liter_eval()</code>.</p>
# </blockquote>
#
# <div style="background-color: #F8F9FA; padding: 15px; border-left: 5px solid #0B7285; border-radius: 8px; margin-top: 20px;">
# <h3 style="color: #0B7285; margin-top: 0;">📚 Recommended Libraries</h3>
# <div style="display: flex; flex-wrap: wrap; gap: 10px; justify-content: flex-start; margin-top: 10px;">
#     <span style="background-color: #0B7285; color: white; padding: 6px 12px; border-radius: 15px; font-size: 0.9em;">pandas</span>
#     <span style="background-color: #17A2B8; color: white; padding: 6px 12px; border-radius: 15px; font-size: 0.9em;">datetime</span>
#     <span style="background-color: #6F42C1; color: white; padding: 6px 12px; border-radius: 15px; font-size: 0.9em;">ast</span>
#     <span style="background-color: #DC3545; color: white; padding: 6px 12px; border-radius: 15px; font-size: 0.9em;">json</span>
# </div>
# </div>

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

# %% [markdown]
# If we print this variable we can see that the `job_skills` and `job_date` values are a string.

# %%
print(data_science_jobs[0])
# Out:
# {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'}

# %% [markdown]
# `datetime`  **Conversion** `(job_date)`
#
#
# First let's import datetime in and test it.

# %%
from datetime import datetime

# show current date and time
datetime.now()
# Out:
# datetime.datetime(2025, 11, 29, 22, 54, 9, 418745)

# %% [markdown]
# Let's test one value from our `job_date` key.

# %%
test_date = data_science_jobs[0]['job_date']

print(test_date)
print(type(test_date))
# Out:
# 2023-05-12
# <class 'str'>

# %% [markdown]
# We'll now use the `.strptime()` method to convert it.

# %%
print(datetime.strptime(test_date , '%Y-%m-%d'))
# Out:
# 2023-05-12 00:00:00

# %% [markdown]
# It works! Let's convert all them in the list.

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]
from datetime import datetime

for job in data_science_jobs:
  job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')

data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': "['Python', 'SQL', 'Machine Learning']",
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': "['Python', 'TensorFlow', 'Deep Learning']",
#   'job_date': datetime.datetime(2023, 5, 15, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': "['SQL', 'R', 'Tableau']",
#   'job_date': datetime.datetime(2023, 5, 10, 0, 0)},
#  {'job_title': 'Business Intelligence Developer',
#   'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']",
#   'job_date': datetime.datetime(2023, 5, 8, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': "['Python', 'Spark', 'Hadoop']",
#   'job_date': datetime.datetime(2023, 5, 18, 0, 0)},
#  {'job_title': 'AI Specialist',
#   'job_skills': "['Python', 'PyTorch', 'AI Ethics']",
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)}]

# %% [markdown]
# `ast` **Conversion** `(job_skills)`

# %%
test_skills = data_science_jobs[0]['job_skills']
print(test_skills)
type(test_skills)
# Out:
# ['Python', 'SQL', 'Machine Learning']
# str

# %%
import ast
print(ast.literal_eval(test_skills))
type(ast.literal_eval(test_skills))
# Out:
# ['Python', 'SQL', 'Machine Learning']
# list

# %% [markdown]
# Nice let's do it for all now! (while doing the datetime).

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

import ast
from datetime import datetime

for job in data_science_jobs:
    job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')
    job['job_skills'] = ast.literal_eval(job['job_skills'])

data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Machine Learning'],
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Deep Learning'],
#   'job_date': datetime.datetime(2023, 5, 15, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['SQL', 'R', 'Tableau'],
#   'job_date': datetime.datetime(2023, 5, 10, 0, 0)},
#  {'job_title': 'Business Intelligence Developer',
#   'job_skills': ['SQL', 'PowerBI', 'Data Warehousing'],
#   'job_date': datetime.datetime(2023, 5, 8, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['Python', 'Spark', 'Hadoop'],
#   'job_date': datetime.datetime(2023, 5, 18, 0, 0)},
#  {'job_title': 'AI Specialist',
#   'job_skills': ['Python', 'PyTorch', 'AI Ethics'],
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)}]
