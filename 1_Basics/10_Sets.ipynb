# %% [markdown]
# # Sets
#
# ## 📊 Quick Comparison Between Python Container Data Types
#
# | Feature           | List 📝                  | Dictionary 🗂️              | Set 🎯                     | Tuple 📦                 |
# |-------------------|--------------------------|----------------------------|----------------------------|--------------------------|
# | **Syntax**        | `[item1, item2, ...]`    | `{'key1': value1, ...}`    | `{item1, item2, ...}`      | `(item1, item2, ...)`    |
# | **Order**         | ✅ Ordered              | ❌ Unordered              | ❌ Unordered              | ✅ Ordered              |
# | **Indexing**      | ✅ (by index)           | ✅ (by key)               | ❌ No                     | ✅ (by index)           |
# | **Duplicate Values** | ✅ Allowed           | 🔑 Keys: ❌, Values: ✅  | ❌ Not allowed            | ✅ Allowed              |
# | **Mutability**    | ✅ Mutable              | ✅ Mutable                | ✅ Mutable                | ❌ Immutable            |
# | **Usage**         | Ordered collections     | Key-value pairs           | Unique items              | Fixed data              |
#
# ---
#
# ## 📝 Notes About Sets
#
# - 🗃️ Used to store multiple items in a single variable
# - 🔍 **Characteristics**:
#   - 🔀 **Unordered** - No guaranteed order
#   - 🔒 **Unchangeable** - Items cannot be changed after creation
#   - 📍 **Unindexed** - Cannot access by position
# - ⚡ **But you can still**:
#   - ➕ **Add** items
#   - ➖ **Remove** items
#
# ---
#
# ## 💡 Importance & Use Cases
#
# - 🧹 **Removing duplicates** from data
# - 🔄 **Set operations**:
#   - 🤝 Union (`|`)
#   - 📍 Intersection (`&`)
#   - ➖ Difference (`-`)
# - 🛠️ **Data cleaning and preparation**
# - 🔍 **Membership testing** (very fast!)
#
# ---
#
# ## 🎯 Set Operations Examples
#
# ```python
# # Creating sets
# set1 = {1, 2, 3, 4, 5}
# set2 = {4, 5, 6, 7, 8}
#
# # Union ✅
# union_set = set1 | set2  # {1, 2, 3, 4, 5, 6, 7, 8}
#
# # Intersection ✅
# intersection_set = set1 & set2  # {4, 5}
#
# # Difference ✅
# difference_set = set1 - set2  # {1, 2, 3}

# %% [markdown]
# ### Examples
# First let's create a set of data science skills.

# %%
# Define a set of data science skills

job_skills = {'tableau' , 'sql' , 'python' , 'power-bi'}

job_skills
# Out:
# {'power-bi', 'python', 'sql', 'tableau'}

# %% [markdown]
# ### Unordered and No Index
# Sets are unorderd and have no index so don't behave completely like lists.
#
# Therefore, we can't use an index to access items.

# %%
job_skills[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 job_skills[1]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ### Add()
# Add an item using add(). Now we're going to add a skill to the list, 'looker'.

# %%
# Adding a skill

job_skills.add('looker')

job_skills
# Out:
# {'looker', 'power-bi', 'python', 'sql', 'tableau'}

# %% [markdown]
# What if we add a skill that's already in the list like sql? It won't duplicate so the skill won't be added. The set is the exact same as before.

# %%
# Adding a skill that already exists doesn't duplicate
job_skills.add('sql')

job_skills
# Out:
# {'looker', 'power-bi', 'python', 'sql', 'tableau'}

# %% [markdown]
# ## Remove()
#
# Remove an item in the set using `remove()`. Let's remove the `'statistics'` item from this set.
#
#
# ### 🪲 Debugging
#
# This is an intentional mistake.
#
# This is used to demonstrate debugging.
#
# **Error:** Tried to remove a skill that does not exist in this set.
#
#
# job_skills.remove('r')
#
# Steps to Debug:
#
# 1. Look at the actual error, can you tell what the problem is?
# 2. If not, then look it up:
# 3. Use a chatbot like ChatGPT or Claude
# 4. Look it up using Google

# %%
# Removing a skill

job_skills.remove('r')

job_skills
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Removing a skill
# ----> 3 job_skills.remove('r')
#       5 job_skills
#
# KeyError: 'r'

# %%
# Removing a skill
job_skills.remove('power-bi')

job_skills
# Out:
# {'looker', 'python', 'sql', 'tableau'}

# %% [markdown]
# ### Set()
# Sets are great for removing repetitive values. Let's create a list of skills called skill_list but these will have repeating skills. If we use set() on this new skill_list. It will show the list as a set (aka remove repeated values).

# %%
skills_list = ['python' , 'sql' , 'statistics' , 'tableau' , 'python' , 'sql' , 'statistics' , 'tableau' ]
set(skills_list)
# Out:
# {'python', 'sql', 'statistics', 'tableau'}

# %% [markdown]
# ### List()
# We can even convert this set back to a list. This will still have the duplicates removed, it will have the unique skills.

# %%
skills_list = list(set(skills_list))
skills_list
# Out:
# ['sql', 'statistics', 'tableau', 'python']
