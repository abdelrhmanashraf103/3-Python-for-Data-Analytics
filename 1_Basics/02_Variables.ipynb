# %% [markdown]
# # 🐍 Python Variables
#
# ## 📝 Creating a Variable
#
# ### 💡 Key Notes
# - ✅ A variable is created the moment you assign a value to it
# - ✅ Variables don't need to be declared with any type
# - ✅ Variables can change types even after they've been set
#
# ---
#
# ## 🎯 Definition
# **Variable**: A named container that stores data values. The variable name goes on the left side of the assignment operator (`=`), and the value or expression you want to assign to that variable goes on the right side.
#
# ### 📋 Basic Syntax

# %%
base_salary = 10000

# %% [markdown]
# You can also perform operations using variables.

# %%
bonus_rate = 0.1
total_salary = base_salary * (1 + bonus_rate)

# %%
total_salary
# Out:
# 11000.0

# %% [markdown]
# ### Variables aren't only numbers
#
# **Notes**
# - We can store all different kinds of data in variables
# - Note: We'll cover more on types in a bit
#
# **Example**
#
# - Create variables to store the following information about a job posting:
#     * Job ID (integer) 🆔
#     * Company Name (string) 🏢
#     * Salary Rate (string, but consider how you might store this as a numerical type for calculations) 💰
#     * Job Work From Home (boolean) 🏠

# %%
job_id = 101
company_name = "Samsung"
job_title = "Data Analyst"
job_salary = 12500
job_work_from_home = False

# %%
# This won't print out the variable name.
print("Job ID:      ", job_id)
print("Company Name:", company_name)
print("Job Title:   ", job_title)
print("Salary:      ", job_salary)
print("WFH:         ", job_work_from_home)
# Out:
# Job ID:       101
# Company Name: Samsung
# Job Title:    Data Analyst
# Salary:       12500
# WFH:          False

# %% [markdown]
# ### Objects in Python
#
# **Key Concept**: Something to understand: everything stored in Python is considered an object. This includes all the data types we've talked about and will talk about.
#
# Objects are a foundational concept in Python, and we'll explore more about what they do in the upcoming sections. 🐍

# %% [markdown]
# # Built-in Types
#
# Python has the following data types built-in by default:
#
# | Type      | Data Type | Example                   |
# |-----------|-----------|---------------------------|
# | Text      | str       | "Data Nerd!"              |
# | Numeric   | int       | 42                        |
# |           | float     | 3.14159                   |
# |           | complex   | 1 + 2j                    |
# | Sequence  | list      | [1, 2, 3]                 |
# |           | tuple     | (1, 2, 3)                 |
# |           | range     | range(10)                 |
# | Mapping   | dict      | {"key": "value"}          |
# | Set       | set       | {1, 2, 3}                 |
# |           | frozenset | frozenset([1, 2, 3])      |
# | Boolean   | bool      | True or False             |
# | Binary    | bytes     | b"Data"                   |
# |           | bytearray | bytearray(5)              |
# |           | memoryview| memoryview(b"Data")       |
# | None      | NoneType  | None                      |

# %% [markdown]
# | Data Type   | Syntax         | Example                                      |
# |-------------|----------------|----------------------------------------------|
# | String      | str()          | str('Hello World')                           |
# | Integer     | int()          | int(20)                                      |
# | Float       | float()        | float(20.5)                                  |
# | Complex     | complex()      | complex(1j)                                  |
# | List        | list()         | list(('apple', 'banana', 'cherry'))          |
# | Tuple       | tuple()        | tuple(('apple', 'banana', 'cherry'))         |
# | Range       | range()        | range(6)                                     |
# | Dictionary  | dict()         | dict(name='John', age=36)                    |
# | Set         | set()          | set(('apple', 'banana', 'cherry'))           |
# | Frozenset   | frozenset()    | frozenset(('apple', 'banana', 'cherry'))     |
# | Boolean     | bool()         | bool(5)                                      |
# | Bytes       | bytes()        | bytes(5)                                     |
# | Bytearray   | bytearray()    | bytearray(5)                                 |
# | Memoryview  | memoryview()   | memoryview(bytes(5))                         |
